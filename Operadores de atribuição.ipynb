# %%
import pandas as pd
import numpy as np

# %%
print("The Show must go on!")
# Out:
# The Show must go on!

# %%
saldo = 500
saldo += 200
print(saldo)
# Out:
# 700

# %%
saldo = 500
saldo -= 200
print(saldo)
# Out:
# 300

# %%
saldo = 500
saldo *= 2
print(saldo)
# Out:
# 1000

# %%
saldo = 500
saldo /= 5
print(saldo)
# Out:
# 100.0

# %%
saldo = 500
saldo //= 5
print(saldo)
# Out:
# 100

# %%
saldo = 500
saldo %= 480
print(saldo)
# Out:
# 20

# %%
saldo = 2
saldo **= 4
print(saldo)
# Out:
# 16
