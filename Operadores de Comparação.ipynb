# %%
import pandas as pd
import numpy as np

# %%
print("The Show must go on!")
# Out:
# The Show must go on!

# %%
numero3 = 5
numero4 = 4

x = numero3 > numero4
y = numero3 >= numero4
k = numero3 < numero4
l = numero3 <= numero4
m = numero3 == numero4
n = numero3 != numero4
print(x, y, k, l, m, n)
# Out:
# True True False False False True
