# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn
import scipy
import sklearn

# %%
print("The Show must go on!")
# Out:
# The Show must go on!

# %%
numero1 = float(input("Digite o preço da bandeja de queijo: R$ "))

# %%
numero2 = float(input("Digite o preço da bandeja de peito de peru: R$ "))

# %%
gastos = numero1 + numero2
print(gastos)
# Out:
# 30.0

# %%
numero3 = 5
numero4 = 4

x = numero3 + numero4
y = numero3 - numero4
k = numero3 * numero4
l = numero3 ** numero4
m = numero3 / numero4
n = numero3 // numero4
print(x, y, k, l, m, n)
# Out:
# 9 1 20 625 1.25 1

# %%
for v in [x, y, k, l, m, n]:
    print(v, "->", type(v).__name__)
# Out:
# 9 -> int
# 1 -> int
# 20 -> int
# 625 -> int
# 1.25 -> float
# 1 -> int
